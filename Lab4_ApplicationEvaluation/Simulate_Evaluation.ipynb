# %% [markdown]
# # Evaluate application using manual data set
#
# ## Objective
#
# This tutorial provides a step-by-step guide on how to use the simulator to automate interaction with the LLM. This will allow user to create synthetic test data. After data has been simulated we use the evaluation SDK to score the output/
#
# This tutorial uses the following Azure AI services:
#
# - [azure-ai-evaluation](https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/evaluate-sdk)
#
# ## Before you begin
#
# ### Installation
#
# Install the following packages required to execute this notebook.

# %%
# %pip install azure-ai-evaluation
# %pip install promptflow-azure
# %pip install azure-identity
# %pip install --upgrade openai
# %pip install python-dotenv
#%pip install marshmallow==3.23.3
# Out:
# Requirement already satisfied: azure-ai-evaluation in /opt/conda/lib/python3.12/site-packages (1.12.0)
# Requirement already satisfied: pyjwt>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (2.8.0)
# Requirement already satisfied: azure-identity>=1.16.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (1.25.1)
# Requirement already satisfied: azure-core>=1.30.2 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (1.36.0)
# Requirement already satisfied: nltk>=3.9.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (12.27.0)
# Requirement already satisfied: httpx>=0.25.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (0.27.0)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (2.2.2)
# Requirement already satisfied: openai>=1.108.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (2.5.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (0.18.6)
# Requirement already satisfied: msrest>=0.6.21 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: aiohttp>=3.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-evaluation) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.18.0)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.5)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.11.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in /opt/conda/lib/python3.12/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (2.1.3)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.66.5)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (2.8.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2023.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation) (0.2.8)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (2.1.3)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /opt/conda/lib/python3.12/site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.66.5)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.108.0->azure-ai-evaluation) (2.8.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2023.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation) (0.2.8)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.3.1)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai>=1.108.0->azure-ai-evaluation) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.3.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.21)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: promptflow-azure in /opt/conda/lib/python3.12/site-packages (1.18.1)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.29.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.36.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (4.14.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.25.1)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /opt/conda/lib/python3.12/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (12.27.0)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.18.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (2.8.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.23.0)
# Requirement already satisfied: tqdm<5.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.66.5)
# Requirement already satisfied: strictyaml<2.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: azure-storage-file-share in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.23.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.22.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: isodate<1.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: promptflow-azure in /opt/conda/lib/python3.12/site-packages (1.18.1)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.29.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.36.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (4.14.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.25.1)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /opt/conda/lib/python3.12/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (12.27.0)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (1.18.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-azure) (2.8.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.23.0)
# Requirement already satisfied: tqdm<5.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.66.5)
# Requirement already satisfied: strictyaml<2.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: azure-storage-file-share in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.23.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.22.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: isodate<1.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: typing-extensions<5.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.11.0)
# Requirement already satisfied: azure-monitor-opentelemetry in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.8.1)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.5)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: argcomplete>=3.2.3 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.6.3)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.0.0b44)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.13.1)
# Requirement already satisfied: flask-cors<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.3.2)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.27.0)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (24.3.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.2.2)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.4.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.18.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.1.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.0.34)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.2)
# Requirement already satisfied: aiohttp>=3.0 in /opt/conda/lib/python3.12/site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (3.12.15)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.35 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk~=1.35 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.9.0)
# Requirement already satisfied: typing-extensions<5.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.11.0)
# Requirement already satisfied: azure-monitor-opentelemetry in /opt/conda/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.8.1)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.5)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: argcomplete>=3.2.3 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.6.3)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.0.0b44)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.13.1)
# Requirement already satisfied: flask-cors<7.0.0,>=6.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.3.2)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.27.0)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (24.3.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.2.2)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.4.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.18.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.1.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.0.34)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.2)
# Requirement already satisfied: aiohttp>=3.0 in /opt/conda/lib/python3.12/site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (3.12.15)
# Requirement already satisfied: fixedint==0.1.6 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.35 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk~=1.35 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: psutil<8,>=5.9 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.9.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: flask>=0.9 in /opt/conda/lib/python3.12/site-packages (from flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.3)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/conda/lib/python3.12/site-packages (from flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.3)
# Requirement already satisfied: aniso8601>=0.82 in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.0.1)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.30.2)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (4.0.7)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.10.6)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.2.1)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.7.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: flask>=0.9 in /opt/conda/lib/python3.12/site-packages (from flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.3)
# Requirement already satisfied: Werkzeug>=0.7 in /opt/conda/lib/python3.12/site-packages (from flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.3)
# Requirement already satisfied: aniso8601>=0.82 in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.0.1)
# Requirement already satisfied: referencing in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.30.2)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (4.0.7)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (4.2.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.7)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.10.6)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.2.1)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.7.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.29.5)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2023.3)
# Requirement already satisfied: docstring_parser in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.17.0)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.119.0)
# Requirement already satisfied: filetype>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.2.0)
# Requirement already satisfied: promptflow-tracing==1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.18.1)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.18.6)
# Requirement already satisfied: openai in /opt/conda/lib/python3.12/site-packages (from promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.5.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.38.0)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.29.5)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2023.3)
# Requirement already satisfied: docstring_parser in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.17.0)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.119.0)
# Requirement already satisfied: filetype>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.2.0)
# Requirement already satisfied: promptflow-tracing==1.18.1 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.18.1)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /opt/conda/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.18.6)
# Requirement already satisfied: openai in /opt/conda/lib/python3.12/site-packages (from promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.5.0)
# Requirement already satisfied: tiktoken>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.12.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.1)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.5)
# Requirement already satisfied: tiktoken>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.12.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.1)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /opt/conda/lib/python3.12/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.18.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.21)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in /opt/conda/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.48.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.8.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from flask>=0.9->flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.6)
# ...
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-api~=1.35->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (7.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: opentelemetry-util-http==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.14.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.59b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.10.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.16.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.59b0 in /opt/conda/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.59b0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug>=0.7->flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.1.3)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.12/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.3.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.12/site-packages (from Werkzeug>=0.7->flask-cors<7.0.0,>=6.0.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.1.3)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.12/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.35->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.21.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.20.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.3.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.35->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.21.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.20.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.12/site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2024.9.11)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.11.1)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.12/site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2024.9.11)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai->promptflow-tracing==1.18.1->promptflow-core<2.0.0,>=1.18.1->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.11.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: azure-identity in /opt/conda/lib/python3.12/site-packages (1.25.1)
# Requirement already satisfied: azure-core>=1.31.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (4.11.0)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.5)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.8.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.10.5)
# Requirement already satisfied: azure-identity in /opt/conda/lib/python3.12/site-packages (1.25.1)
# Requirement already satisfied: azure-core>=1.31.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.36.0)
# Requirement already satisfied: cryptography>=2.5 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (44.0.1)
# Requirement already satisfied: msal>=1.30.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.12/site-packages (from azure-identity) (4.11.0)
# Requirement already satisfied: requests>=2.21.0 in /opt/conda/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.5)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.8.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in /opt/conda/lib/python3.12/site-packages (2.5.0)
# Requirement already satisfied: openai in /opt/conda/lib/python3.12/site-packages (2.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai) (4.66.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/conda/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.12/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/conda/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.12/site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Parameters and imports

# %%
import pandas as pd
import os
import json
import importlib.resources as pkg_resources
import requests
from typing import Any, Dict, List, Optional
from pathlib import Path
from pprint import pprint
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import GroundednessEvaluator
from azure.ai.evaluation.simulator import Simulator
from openai import AzureOpenAI
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from dotenv import load_dotenv
# Using mock endpoint for testing (no APPLICATION_ENDPOINT/KEY needed)
from application_endpoint_mock import ApplicationEndpoint

# Load .env file - explicitly specify the path
env_path = Path(".env")
load_dotenv(dotenv_path=env_path)
print(f"✅ Loaded .env from: {env_path.absolute()}")
print(f"   AZURE_OPENAI_ENDPOINT: {os.environ.get('AZURE_OPENAI_ENDPOINT')}")
print(f"   AZURE_OPENAI_DEPLOYMENT: {os.environ.get('AZURE_OPENAI_DEPLOYMENT')}")
# Out:
# ✅ Loaded .env from: /workspaces/eval-hack-2025/Lab4_ApplicationEvaluation/.env
#    AZURE_OPENAI_ENDPOINT: https://ai-eval-hack.cognitiveservices.azure.com/
#    AZURE_OPENAI_DEPLOYMENT: gpt-4.1

# %% [markdown]
# We set up the configuration for AI Foundry Projet and model config. This will be use for result visibility and use LLM as the judge.

# %%
project_scope = {
    "subscription_id": os.environ.get("AZURE_SUBSCRIPTION_ID"),
    "resource_group_name": os.environ.get("AZURE_AI_FOUNDRY_RESOURCE_GROUP"),
    "project_name": os.environ.get("AZURE_AI_FOUNDRY_PROJECT_NAME"),
}
model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT"),
}

# %% [markdown]
# AI Foundry SDK provide the similuator to be able to simulate the interaction with the LLM.

# %%
simulator = Simulator(model_config=model_config)
# Out:
# Class Simulator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %% [markdown]
# Connect application end point to the simulator. The call back function map the input and output between application endpoint and the suitable format for the evaluator.

# %%
async def callback(
    messages: List[Dict],
    stream: bool = False,
    session_state: Any = None,  # noqa: ANN401
    context: Optional[Dict[str, Any]] = None,
) -> dict:
    messages_list = messages["messages"]
    # get last message
    latest_message = messages_list[-1]
    query = latest_message["content"]
    context = latest_message.get("context", None)
    # call model end point
    application_endpoint = ApplicationEndpoint()
    response = application_endpoint(query, None)
    print(response)
    # we are formatting the response to follow the openAI chat protocol format
    formatted_response = {
        "content": response["response"],
        "role": "assistant",
        "context": context,
    }
    messages["messages"].append(formatted_response)
    return {"messages": messages["messages"], "stream": stream, "session_state": session_state, "context": context}

# %% [markdown]
# We trigger the simular and provide some configuration where we will ask the simular to try to complete two task with 2 turn of the conversation.

# %%
outputs = await simulator(
    target=callback,
    num_queries=2,
    max_conversation_turns=2,
    tasks=[
        f"I want to learn more about Responsible AI",
        f"I want to know how to implement Responsible AI in my organization",
    ],
)
# Out:
# Generating:   0%|                                                        | 0/4 [00:00<?, ?message/s]
# 🔧 Using MOCK Application Endpoint (for testing only)
# 📝 Mock query: I'm interested in Responsible AI. Can you tell me ...
# 📝 Mock response: According to the Responsible AI Standard: Microsoft's Responsible AI Standard provides a framework f...
# {'query': "I'm interested in Responsible AI. Can you tell me what the content of the provided text is, and how it relates to Responsible AI principles?", 'response': "According to the Responsible AI Standard: Microsoft's Responsible AI Standard provides a framework for developing AI systems responsibly. It covers principles including fairness, reliability, safety, privacy, inclusiveness, transparency, and accountability. Each principle provides guidance for building trustworthy AI systems."}
# Generating:  25%|████████████                                    | 1/4 [00:02<00:07,  2.43s/message]
# 🔧 Using MOCK Application Endpoint (for testing only)
# 📝 Mock query: Thanks for explaining the principles! Can you give...
# 📝 Mock response: Microsoft's Responsible AI Standard emphasizes that AI systems should treat all people fairly. This ...
# {'query': 'Thanks for explaining the principles! Can you give me some real-world examples of how these Responsible AI principles are applied in practice? For instance, how do companies ensure fairness or transparency when deploying AI systems?', 'response': "Microsoft's Responsible AI Standard emphasizes that AI systems should treat all people fairly. This includes identifying and mitigating unfair bias in AI systems."}
# Generating:  50%|████████████████████████                        | 2/4 [00:04<00:04,  2.48s/message]
# 🔧 Using MOCK Application Endpoint (for testing only)
# 📝 Mock query: I'm interested in implementing Responsible AI in m...
# 📝 Mock response: Microsoft's Responsible AI Standard provides a framework for developing AI systems responsibly. It c...
# {'query': "I'm interested in implementing Responsible AI in my organization. Can you tell me what information or resources are available to help me get started, and are there any specific guidelines or frameworks I should be aware of?", 'response': "Microsoft's Responsible AI Standard provides a framework for developing AI systems responsibly. It covers principles including fairness, reliability, safety, privacy, inclusiveness, transparency, and accountability. Each principle provides guidance for building trustworthy AI systems."}
# Generating:  75%|████████████████████████████████████            | 3/4 [00:07<00:02,  2.47s/message]
# 🔧 Using MOCK Application Endpoint (for testing only)
# 📝 Mock query: Thanks for sharing that framework! Could you provi...
# 📝 Mock response: Based on Microsoft's Responsible AI guidelines: Microsoft's Responsible AI Standard provides a frame...
# {'query': 'Thanks for sharing that framework! Could you provide examples of how organizations have successfully applied these principles in practice? Also, are there any tools or assessment checklists that can help me evaluate whether our current AI projects align with Responsible AI standards?', 'response': "Based on Microsoft's Responsible AI guidelines: Microsoft's Responsible AI Standard provides a framework for developing AI systems responsibly. It covers principles including fairness, reliability, safety, privacy, inclusiveness, transparency, and accountability. Each principle provides guidance for building trustworthy AI systems."}
# Generating: 100%|████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.51s/message]
# Generating: 100%|████████████████████████████████████████████████| 4/4 [00:10<00:00,  2.51s/message]

# %% [markdown]
# After simulation has been completed we can have a write a output to a file.

# %%
simulated_output_file = Path("simulated_output.json")
with simulated_output_file.open("a") as f:
    json.dump(outputs, f)

# %% [markdown]
# The simulated response include the full conversation of the simulator with the application. In order to evaluate the output we need to convert to the standard format using to_eval_qr_json_lines

# %%
eval_data_file = Path("simulated_eval_data.jsonl")
with eval_data_file.open("w") as file:
    for output in outputs:
        file.write(output.to_eval_qr_json_lines())

# %% [markdown]
# Please provide Azure AI Project details so that traces and eval results are pushing in the project in Azure AI Studio.

# %%
azure_ai_project = {
    "subscription_id": os.environ["AZURE_SUBSCRIPTION_ID"],
    "resource_group_name": os.environ["AZURE_AI_FOUNDRY_RESOURCE_GROUP"],
    "project_name": os.environ["AZURE_AI_FOUNDRY_PROJECT_NAME"],
}

# %% [markdown]
# Following code reads Json file "data.jsonl" which contains inputs to the Application Target function. It provides question, context on each line.

# %%
df = pd.read_json("simulated_eval_data.jsonl", lines=True)
print(df.head())
# Out:
#                                                query  \
# 0  I'm interested in Responsible AI. Can you tell...
# 1  Thanks for explaining the principles! Can you ...
# 2  I'm interested in implementing Responsible AI ...
# 3  Thanks for sharing that framework! Could you p...
#
#                                             response context
# 0  According to the Responsible AI Standard: Micr...    None
# 1  Microsoft's Responsible AI Standard emphasizes...    None
# 2  Microsoft's Responsible AI Standard provides a...    None
# 3  Based on Microsoft's Responsible AI guidelines...    None

# %% [markdown]
# To use Relevance and Cohenrence Evaluator, we will Azure Open AI model details as a Judge that can be passed as model config.

# %%
import os

model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT"),
    "api_key": os.environ.get("AZURE_OPENAI_KEY"),
}

# %% [markdown]
# The Following code runs Evaluate API and uses Content Safety, Relevance and Coherence Evaluator to evaluate results from different models.
#
# The following are the few parameters required by Evaluate API.
#
# +   Data file (Prompts): It represents data file 'simulated_eval_data.jsonl' in JSON format. Each line contains question, context for evaluators.
#
# +   Evaluators: List of evaluators is provided, to evaluate given prompts (questions) as input and output (answers) from LLM models.
#
# Note: You can see that similarity is commented out as this is simulated data and we dont have ground truth from SME to validate.

# %%
import pathlib
from datetime import datetime
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import (
    ContentSafetyEvaluator,
    RelevanceEvaluator,
    CoherenceEvaluator,
    GroundednessEvaluator,
    FluencyEvaluator,
    SimilarityEvaluator,
)
from application_endpoint import ApplicationEndpoint


content_safety_evaluator = ContentSafetyEvaluator(
    azure_ai_project=azure_ai_project, credential=DefaultAzureCredential()
)
relevance_evaluator = RelevanceEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
similarity_evaluator = SimilarityEvaluator(model_config)

path = str(pathlib.Path(pathlib.Path.cwd())) + "/simulated_eval_data.jsonl"

results = evaluate(
    evaluation_name=f"Simulated-Eval-Run-{datetime.now().strftime("%Y-%m-%d")}",
    data=path,
    evaluators={
        "content_safety": content_safety_evaluator,
        "coherence": coherence_evaluator,
        "relevance": relevance_evaluator,
        "groundedness": groundedness_evaluator,
        "fluency": fluency_evaluator,
        # "similarity": similarity_evaluator,
    },
    azure_ai_project=azure_ai_project,
    evaluator_config={
        "content_safety": {"column_mapping": {"query": "${data.query}", "response": "${data.response}"}},
        "coherence": {"column_mapping": {"response": "${data.response}", "query": "${data.query}"}},
        "relevance": {
            "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        "groundedness": {
            "column_mapping": {
                "response": "${data.response}",
                "context": "${data.context}",
                "query": "${data.query}",
            }
        },
        "fluency": {
            "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        },
        # "similarity": {
        #     "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
        # },
    },
)
# Out:
# Class ContentSafetyEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ViolenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ViolenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SexualEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SexualEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SelfHarmEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SelfHarmEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class HateUnfairnessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class HateUnfairnessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# 2025-10-20 14:18:26 +0000 139697896548032 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:26 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 4.23 seconds.
# 2025-10-20 14:18:26 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 4.23 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.86 seconds. Estimated time for incomplete lines: 1.72 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.86 seconds. Estimated time for incomplete lines: 1.72 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 0.59 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 0.59 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.47 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697896548032 execution.bulk     INFO     Average execution time for completed lines: 0.47 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "relevance_20251020_141825_578210"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.578210+00:00"
# Duration: "0:00:02.001003"
#
# ======= Run Summary =======
#
# Run name: "relevance_20251020_141825_578210"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.578210+00:00"
# Duration: "0:00:02.001003"
#
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 2.13 seconds. Estimated time for incomplete lines: 6.39 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 1.07 seconds. Estimated time for incomplete lines: 2.14 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 2.13 seconds. Estimated time for incomplete lines: 6.39 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 1.07 seconds. Estimated time for incomplete lines: 2.14 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 0.73 seconds. Estimated time for incomplete lines: 0.73 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 0.73 seconds. Estimated time for incomplete lines: 0.73 seconds.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 2.25 seconds. Estimated time for incomplete lines: 6.75 seconds.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 2.25 seconds. Estimated time for incomplete lines: 6.75 seconds.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 1.13 seconds. Estimated time for incomplete lines: 2.26 seconds.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 2.23 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 1.13 seconds. Estimated time for incomplete lines: 2.26 seconds.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Finished 1 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 2.23 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 1.12 seconds. Estimated time for incomplete lines: 2.24 seconds.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Finished 2 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 1.12 seconds. Estimated time for incomplete lines: 2.24 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:27 +0000 139697854584512 execution.bulk     INFO     Average execution time for completed lines: 0.59 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 0.82 seconds. Estimated time for incomplete lines: 0.82 seconds.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 0.82 seconds. Estimated time for incomplete lines: 0.82 seconds.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 0.82 seconds. Estimated time for incomplete lines: 0.82 seconds.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Finished 3 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 0.82 seconds. Estimated time for incomplete lines: 0.82 seconds.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 0.67 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697300960960 execution.bulk     INFO     Average execution time for completed lines: 0.67 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 0.69 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:18:28 +0000 139697904940736 execution.bulk     INFO     Average execution time for completed lines: 0.69 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "coherence_20251020_141825_570721"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.570721+00:00"
# Duration: "0:00:03.001457"
#
# ======= Run Summary =======
#
# Run name: "groundedness_20251020_141825_602605"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.602605+00:00"
# Duration: "0:00:03.001963"
#
# ======= Run Summary =======
#
# Run name: "fluency_20251020_141825_614181"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.614181+00:00"
# Duration: "0:00:03.000843"
#
# ======= Run Summary =======
#
# Run name: "coherence_20251020_141825_570721"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.570721+00:00"
# Duration: "0:00:03.001457"
#
# ======= Run Summary =======
#
# Run name: "groundedness_20251020_141825_602605"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.602605+00:00"
# Duration: "0:00:03.001963"
#
# ======= Run Summary =======
#
# Run name: "fluency_20251020_141825_614181"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.614181+00:00"
# Duration: "0:00:03.000843"
#
# 2025-10-20 14:19:23 +0000 139698052785856 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:19:23 +0000 139698052785856 execution.bulk     INFO     Average execution time for completed lines: 14.42 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-10-20 14:19:23 +0000 139698052785856 execution.bulk     INFO     Finished 4 / 4 lines.
# 2025-10-20 14:19:23 +0000 139698052785856 execution.bulk     INFO     Average execution time for completed lines: 14.42 seconds. Estimated time for incomplete lines: 0.0 seconds.
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# Aggregated metrics for evaluator is not a dictionary will not be logged as metrics
# ======= Run Summary =======
#
# Run name: "content_safety_20251020_141825_575967"
# Run status: "Completed"
# Start time: "2025-10-20 14:18:25.575967+00:00"
# Duration: "0:00:57.702149"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "content_safety": {
#         "status": "Completed",
#         "duration": "0:00:57.702149",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:03.001457",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:02.001003",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:03.001963",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": null
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:03.000843",
#         "completed_lines": 4,
#         "failed_lines": 0,
#         "log_path": null
#     }
# }
#
# ====================================================
# ---------------------------------------------------------------------------
# HttpResponseError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_eval_run.py:447, in EvalRun.log_artifact(self, artifact_folder, artifact_name)
#     446         with open(local, "rb") as fp:
# --> 447             blob_client.upload_blob(fp, overwrite=True)
#     448 except HttpResponseError as ex:
#
# File /opt/conda/lib/python3.12/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#
# File /opt/conda/lib/python3.12/site-packages/azure/storage/blob/_blob_client.py:631, in BlobClient.upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     630 if blob_type == BlobType.BlockBlob:
# --> 631     return upload_block_blob(**options)
#     632 if blob_type == BlobType.PageBlob:
#
# File /opt/conda/lib/python3.12/site-packages/azure/storage/blob/_upload_helpers.py:197, in upload_block_blob(client, stream, overwrite, encryption_options, blob_settings, headers, validate_content, max_concurrency, length, **kwargs)
#     196 try:
# --> 197     process_storage_error(error)
#     198 except ResourceModifiedError as mod_error:
#
# File /opt/conda/lib/python3.12/site-packages/azure/storage/blob/_shared/response_handlers.py:195, in process_storage_error(storage_error)
#     193 try:
#     194     # `from None` prevents us from double printing the exception (suppresses generated layer error context)
# --> 195     exec("raise error from None")  # pylint: disable=exec-used # nosec
#     196 except SyntaxError as exc:
#
# File <string>:1
#
# HttpResponseError: Key based authentication is not permitted on this storage account.
# RequestId:55daa969-501e-0042-79cc-41c279000000
# Time:2025-10-20T14:19:28.0001720Z
# ErrorCode:KeyBasedAuthenticationNotPermitted
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>KeyBasedAuthenticationNotPermitted</Code><Message>Key based authentication is not permitted on this storage account.
# RequestId:55daa969-501e-0042-79cc-41c279000000
# Time:2025-10-20T14:19:28.0001720Z</Message></Error>
#
# The above exception was the direct cause of the following exception:
#
# EvaluationException                       Traceback (most recent call last)
# Cell In[12], line 26
#      22 similarity_evaluator = SimilarityEvaluator(model_config)
#      24 path = str(pathlib.Path(pathlib.Path.cwd())) + "/simulated_eval_data.jsonl"
# ---> 26 results = evaluate(
#      27     evaluation_name=f"Simulated-Eval-Run-{datetime.now().strftime("%Y-%m-%d")}",
#      28     data=path,
#      29     evaluators={
#      30         "content_safety": content_safety_evaluator,
#      31         "coherence": coherence_evaluator,
#      32         "relevance": relevance_evaluator,
#      33         "groundedness": groundedness_evaluator,
#      34         "fluency": fluency_evaluator,
#      35         # "similarity": similarity_evaluator,
#      36     },
#      37     azure_ai_project=azure_ai_project,
#      38     evaluator_config={
#      39         "content_safety": {"column_mapping": {"query": "${data.query}", "response": "${data.response}"}},
#      40         "coherence": {"column_mapping": {"response": "${data.response}", "query": "${data.query}"}},
#      41         "relevance": {
#      42             "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
#      43         },
#      44         "groundedness": {
#      45             "column_mapping": {
#      46                 "response": "${data.response}",
#      47                 "context": "${data.context}",
#      48                 "query": "${data.query}",
#      49             }
#      50         },
#      51         "fluency": {
#      52             "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
#      53         },
#      54         # "similarity": {
#      55         #     "column_mapping": {"response": "${data.response}", "context": "${data.context}", "query": "${data.query}"}
#      56         # },
#      57     },
#      58 )
#
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_evaluate.py:839, in evaluate(data, evaluators, evaluation_name, target, evaluator_config, azure_ai_project, output_path, fail_on_evaluator_errors, tags, **kwargs)
#     831 if not isinstance(e, EvaluationException):
#     832     raise EvaluationException(
#     833         message=str(e),
#     834         target=ErrorTarget.EVALUATE,
#     835         category=ErrorCategory.FAILED_EXECUTION,
#     836         blame=ErrorBlame.SYSTEM_ERROR,
#     837     ) from e
# --> 839 raise e
#
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_evaluate.py:796, in evaluate(data, evaluators, evaluation_name, target, evaluator_config, azure_ai_project, output_path, fail_on_evaluator_errors, tags, **kwargs)
#     794     user_agent: Optional[str] = kwargs.get("user_agent")
#     795     with UserAgentSingleton().add_useragent_product(user_agent) if user_agent else contextlib.nullcontext():
# --> 796         return _evaluate(
#     797             evaluation_name=evaluation_name,
#     798             target=target,
#     799             data=data,
#     800             evaluators_and_graders=evaluators,
#     801             evaluator_config=evaluator_config,
#     802             azure_ai_project=azure_ai_project,
#     803             output_path=output_path,
#     804             fail_on_evaluator_errors=fail_on_evaluator_errors,
#     805             tags=tags,
#     806             **kwargs,
#     807         )
#     808 except Exception as e:
#     809     # Handle multiprocess bootstrap error
#     810     bootstrap_error = (
#     811         "An attempt has been made to start a new process before the\n        "
#     812         "current process has finished its bootstrapping phase."
#     813     )
#
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_evaluate.py:978, in _evaluate(evaluators_and_graders, evaluation_name, target, data, evaluator_config, azure_ai_project, output_path, fail_on_evaluator_errors, tags, **kwargs)
#     976     studio_url = None
#     977     if trace_destination:
# --> 978         studio_url = _log_metrics_and_instance_results(
#     979             metrics, results_df, trace_destination, None, evaluation_name, name_map, tags=tags, **kwargs
#     980         )
#     982 result_df_dict = results_df.to_dict("records")
#     983 result: EvaluationResult = {"rows": result_df_dict, "metrics": metrics, "studio_url": studio_url}  # type: ignore
#
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_utils.py:269, in _log_metrics_and_instance_results(metrics, instance_results, trace_destination, run, evaluation_name, name_map, tags, **kwargs)
#     266 with open(tmp_path, "w", encoding=DefaultOpenEncoding.WRITE) as f:
#     267     f.write(instance_results.to_json(orient="records", lines=True))
# --> 269 ev_run.log_artifact(tmpdir, artifact_name)
#     271 # Using mlflow to create a dummy run since once created via PF show traces of dummy run in UI.
#     272 # Those traces can be confusing.
#     273 # adding these properties to avoid showing traces if a dummy run is created.
#     274 # We are doing that only for the pure evaluation runs.
#     275 if run is None:
#
# File /opt/conda/lib/python3.12/site-packages/azure/ai/evaluation/_evaluate/_eval_run.py:454, in EvalRun.log_artifact(self, artifact_folder, artifact_name)
#     449     if ex.status_code == 403:
#     450         msg = (
#     451             "Failed to upload evaluation run to the cloud due to insufficient permission to access the storage."
#     452             " Please ensure that the necessary access rights are granted."
#     453         )
# --> 454         raise EvaluationException(
#     455             message=msg,
#     456             target=ErrorTarget.EVAL_RUN,
#     457             category=ErrorCategory.FAILED_REMOTE_TRACKING,
#     458             blame=ErrorBlame.USER_ERROR,
#     459             tsg_link="https://aka.ms/azsdk/python/evaluation/remotetracking/troubleshoot",
#     460         ) from ex
#     462     raise ex
#     464 # To show artifact in UI we will need to register it. If it is a promptflow run,
#     465 # we are rewriting already registered artifact and need to skip this step.
#
# EvaluationException: (UserError) Failed to upload evaluation run to the cloud due to insufficient permission to access the storage. Please ensure that the necessary access rights are granted.
# Visit https://aka.ms/azsdk/python/evaluation/remotetracking/troubleshoot to troubleshoot this issue.

# %% [markdown]
# View the results here or you can also view the result in AI Foundry project.

# %%
pprint(results)

# %%
pd.DataFrame(results["rows"])

# %% [markdown]
# We can also generate adversial type conversation where we will try to hack or jail break the application

# %%
from azure.ai.evaluation.simulator import AdversarialSimulator, AdversarialScenario

adversarial_outputs = await simulator(
    scenario=AdversarialScenario.ADVERSARIAL_SEARCH, max_conversation_turns=2, max_simulation_results=2, target=callback
)

# %% [markdown]
# We can print the conversation to review.

# %%
with Path("adversarial_outputs.jsonl").open("w") as f:
    json.dump(adversarial_outputs, f)
